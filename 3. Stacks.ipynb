# %% [markdown]
# # 8.3 🥞 Stacks (LIFO)
#
# A **Stack** is a linear data structure that follows the **LIFO (Last-In, First-Out)** principle. Where elements are inserted and removed from a single end known as the top. It plays a crucial role in areas such as function call management, expression evaluation, and backtracking algorithms.
#
# **Key Topics Covered:**
# * **The Mental Model:** LIFO (Stack of Plates).
# * **Implementation:** Using Python Lists correctly.
# * **System Architecture:** The CPU Call Stack.
# * **Algorithms:** Undo, Syntax Parsing, and DFS.

# %% [markdown]
# ## 1. 🥞 The Mental Model (LIFO)
#
# Imagine a stack of plates in a cafeteria.
#
# 1.  **Push:** You place a new plate on **top**.
# 2.  **Pop:** You can only take the plate from the **top**.
# 3.  **Peek:** You can see the top plate without removing it.
#
# You cannot access the bottom plate without removing all the ones above it.

# %%
from typing import Any, Optional, List

class Stack:
    """LIFO Stack implementation using a Python List."""
    def __init__(self):
        # We use a private list. We restrict access so you CANNOT
        # say stack[0]. You must use pop().
        self._items: List[Any] = []

    def is_empty(self) -> bool:
        return len(self._items) == 0

    def push(self, item: Any):
        """Adds to Top. O(1)."""
        self._items.append(item)

    def pop(self) -> Optional[Any]:
        """Removes from Top. O(1)."""
        if self.is_empty():
            return None
        return self._items.pop()

    def peek(self) -> Optional[Any]:
        """Looks at Top. O(1)."""
        if self.is_empty():
            return None
        return self._items[-1]

    def size(self) -> int:
        return len(self._items)

# --- Test ---
s = Stack()
s.push("Page 1 (Home)")
s.push("Page 2 (Settings)")
s.push("Page 3 (Profile)")

print(f"Currently viewing: {s.peek()}")
print(f"Back button pressed: {s.pop()}")
print(f"Now viewing: {s.peek()}")
# Out:
# Currently viewing: Page 3 (Profile)
# Back button pressed: Page 3 (Profile)
# Now viewing: Page 2 (Settings)

# %% [markdown]
# ## 2. ⚙️ The Engineering Reality: The Call Stack
#
# Why are Stacks important? Because **your computer runs on one**.
#
# When you call a function, the CPU "pushes" the function's local variables and return address onto the **Call Stack**. When the function returns, it "pops" that frame off memory.
#
# This is why infinite recursion causes a **Stack Overflow** error: you filled up the stack memory limit.

# %%
def recursive_crash(n):
    print(f"Pushing frame {n} onto the stack...")
    recursive_crash(n + 1)

# Uncommenting this line will crash the kernel with RecursionError
# recursive_crash(1)
# Out:
# Pushing frame 1 onto the stack...
# Pushing frame 2 onto the stack...
# Pushing frame 3 onto the stack...
# Pushing frame 4 onto the stack...
# Pushing frame 5 onto the stack...
# Pushing frame 6 onto the stack...
# Pushing frame 7 onto the stack...
# Pushing frame 8 onto the stack...
# Pushing frame 9 onto the stack...
# Pushing frame 10 onto the stack...
# Pushing frame 11 onto the stack...
# Pushing frame 12 onto the stack...
# Pushing frame 13 onto the stack...
# Pushing frame 14 onto the stack...
# Pushing frame 15 onto the stack...
# Pushing frame 16 onto the stack...
# Pushing frame 17 onto the stack...
# Pushing frame 18 onto the stack...
# Pushing frame 19 onto the stack...
# Pushing frame 20 onto the stack...
# Pushing frame 21 onto the stack...
# Pushing frame 22 onto the stack...
# Pushing frame 23 onto the stack...
# Pushing frame 24 onto the stack...
# Pushing frame 25 onto the stack...
# Pushing frame 26 onto the stack...
# Pushing frame 27 onto the stack...
# Pushing frame 28 onto the stack...
# Pushing frame 29 onto the stack...
# Pushing frame 30 onto the stack...
# Pushing frame 31 onto the stack...
# Pushing frame 32 onto the stack...
# Pushing frame 33 onto the stack...
# Pushing frame 34 onto the stack...
# Pushing frame 35 onto the stack...
# Pushing frame 36 onto the stack...
# Pushing frame 37 onto the stack...
# Pushing frame 38 onto the stack...
# Pushing frame 39 onto the stack...
# Pushing frame 40 onto the stack...
# Pushing frame 41 onto the stack...
# Pushing frame 42 onto the stack...
# Pushing frame 43 onto the stack...
# Pushing frame 44 onto the stack...
# Pushing frame 45 onto the stack...
# Pushing frame 46 onto the stack...
# Pushing frame 47 onto the stack...
# Pushing frame 48 onto the stack...
# Pushing frame 49 onto the stack...
# Pushing frame 50 onto the stack...
# Pushing frame 51 onto the stack...
# Pushing frame 52 onto the stack...
# Pushing frame 53 onto the stack...
# Pushing frame 54 onto the stack...
# Pushing frame 55 onto the stack...
# Pushing frame 56 onto the stack...
# Pushing frame 57 onto the stack...
# Pushing frame 58 onto the stack...
# Pushing frame 59 onto the stack...
# Pushing frame 60 onto the stack...
# Pushing frame 61 onto the stack...
# Pushing frame 62 onto the stack...
# Pushing frame 63 onto the stack...
# Pushing frame 64 onto the stack...
# Pushing frame 65 onto the stack...
# Pushing frame 66 onto the stack...
# Pushing frame 67 onto the stack...
# Pushing frame 68 onto the stack...
# Pushing frame 69 onto the stack...
# Pushing frame 70 onto the stack...
# Pushing frame 71 onto the stack...
# Pushing frame 72 onto the stack...
# Pushing frame 73 onto the stack...
# Pushing frame 74 onto the stack...
# Pushing frame 75 onto the stack...
# Pushing frame 76 onto the stack...
# Pushing frame 77 onto the stack...
# Pushing frame 78 onto the stack...
# Pushing frame 79 onto the stack...
# Pushing frame 80 onto the stack...
# Pushing frame 81 onto the stack...
# Pushing frame 82 onto the stack...
# Pushing frame 83 onto the stack...
# Pushing frame 84 onto the stack...
# Pushing frame 85 onto the stack...
# Pushing frame 86 onto the stack...
# Pushing frame 87 onto the stack...
# Pushing frame 88 onto the stack...
# Pushing frame 89 onto the stack...
# Pushing frame 90 onto the stack...
# Pushing frame 91 onto the stack...
# Pushing frame 92 onto the stack...
# Pushing frame 93 onto the stack...
# Pushing frame 94 onto the stack...
# Pushing frame 95 onto the stack...
# Pushing frame 96 onto the stack...
# Pushing frame 97 onto the stack...
# Pushing frame 98 onto the stack...
# Pushing frame 99 onto the stack...
# Pushing frame 100 onto the stack...
# Pushing frame 101 onto the stack...
# Pushing frame 102 onto the stack...
# Pushing frame 103 onto the stack...
# Pushing frame 104 onto the stack...
# Pushing frame 105 onto the stack...
# Pushing frame 106 onto the stack...
# Pushing frame 107 onto the stack...
# Pushing frame 108 onto the stack...
# Pushing frame 109 onto the stack...
# Pushing frame 110 onto the stack...
# Pushing frame 111 onto the stack...
# Pushing frame 112 onto the stack...
# Pushing frame 113 onto the stack...
# Pushing frame 114 onto the stack...
# Pushing frame 115 onto the stack...
# Pushing frame 116 onto the stack...
# Pushing frame 117 onto the stack...
# Pushing frame 118 onto the stack...
# Pushing frame 119 onto the stack...
# Pushing frame 120 onto the stack...
# Pushing frame 121 onto the stack...
# Pushing frame 122 onto the stack...
# Pushing frame 123 onto the stack...
# Pushing frame 124 onto the stack...
# Pushing frame 125 onto the stack...
# Pushing frame 126 onto the stack...
# Pushing frame 127 onto the stack...
# Pushing frame 128 onto the stack...
# Pushing frame 129 onto the stack...
# Pushing frame 130 onto the stack...
# Pushing frame 131 onto the stack...
# Pushing frame 132 onto the stack...
# Pushing frame 133 onto the stack...
# Pushing frame 134 onto the stack...
# Pushing frame 135 onto the stack...
# Pushing frame 136 onto the stack...
# Pushing frame 137 onto the stack...
# Pushing frame 138 onto the stack...
# Pushing frame 139 onto the stack...
# Pushing frame 140 onto the stack...
# Pushing frame 141 onto the stack...
# Pushing frame 142 onto the stack...
# Pushing frame 143 onto the stack...
# Pushing frame 144 onto the stack...
# Pushing frame 145 onto the stack...
# Pushing frame 146 onto the stack...
# Pushing frame 147 onto the stack...
# Pushing frame 148 onto the stack...
# Pushing frame 149 onto the stack...
# Pushing frame 150 onto the stack...
# Pushing frame 151 onto the stack...
# Pushing frame 152 onto the stack...
# Pushing frame 153 onto the stack...
# Pushing frame 154 onto the stack...
# Pushing frame 155 onto the stack...
# Pushing frame 156 onto the stack...
# Pushing frame 157 onto the stack...
# Pushing frame 158 onto the stack...
# Pushing frame 159 onto the stack...
# Pushing frame 160 onto the stack...
# Pushing frame 161 onto the stack...
# Pushing frame 162 onto the stack...
# Pushing frame 163 onto the stack...
# Pushing frame 164 onto the stack...
# Pushing frame 165 onto the stack...
# Pushing frame 166 onto the stack...
# Pushing frame 167 onto the stack...
# Pushing frame 168 onto the stack...
# Pushing frame 169 onto the stack...
# Pushing frame 170 onto the stack...
# Pushing frame 171 onto the stack...
# Pushing frame 172 onto the stack...
# Pushing frame 173 onto the stack...
# Pushing frame 174 onto the stack...
# Pushing frame 175 onto the stack...
# Pushing frame 176 onto the stack...
# Pushing frame 177 onto the stack...
# Pushing frame 178 onto the stack...
# Pushing frame 179 onto the stack...
# Pushing frame 180 onto the stack...
# Pushing frame 181 onto the stack...
# Pushing frame 182 onto the stack...
# Pushing frame 183 onto the stack...
# Pushing frame 184 onto the stack...
# Pushing frame 185 onto the stack...
# Pushing frame 186 onto the stack...
# Pushing frame 187 onto the stack...
# Pushing frame 188 onto the stack...
# Pushing frame 189 onto the stack...
# Pushing frame 190 onto the stack...
# Pushing frame 191 onto the stack...
# Pushing frame 192 onto the stack...
# Pushing frame 193 onto the stack...
# Pushing frame 194 onto the stack...
# Pushing frame 195 onto the stack...
# Pushing frame 196 onto the stack...
# Pushing frame 197 onto the stack...
# Pushing frame 198 onto the stack...
# Pushing frame 199 onto the stack...
# Pushing frame 200 onto the stack...
# Pushing frame 201 onto the stack...
# Pushing frame 202 onto the stack...
# Pushing frame 203 onto the stack...
# Pushing frame 204 onto the stack...
# Pushing frame 205 onto the stack...
# Pushing frame 206 onto the stack...
# Pushing frame 207 onto the stack...
# Pushing frame 208 onto the stack...
# Pushing frame 209 onto the stack...
# Pushing frame 210 onto the stack...
# Pushing frame 211 onto the stack...
# Pushing frame 212 onto the stack...
# Pushing frame 213 onto the stack...
# Pushing frame 214 onto the stack...
# Pushing frame 215 onto the stack...
# Pushing frame 216 onto the stack...
# Pushing frame 217 onto the stack...
# Pushing frame 218 onto the stack...
# Pushing frame 219 onto the stack...
# Pushing frame 220 onto the stack...
# Pushing frame 221 onto the stack...
# Pushing frame 222 onto the stack...
# Pushing frame 223 onto the stack...
# Pushing frame 224 onto the stack...
# Pushing frame 225 onto the stack...
# Pushing frame 226 onto the stack...
# Pushing frame 227 onto the stack...
# Pushing frame 228 onto the stack...
# Pushing frame 229 onto the stack...
# Pushing frame 230 onto the stack...
# Pushing frame 231 onto the stack...
# Pushing frame 232 onto the stack...
# Pushing frame 233 onto the stack...
# Pushing frame 234 onto the stack...
# Pushing frame 235 onto the stack...
# Pushing frame 236 onto the stack...
# Pushing frame 237 onto the stack...
# Pushing frame 238 onto the stack...
# Pushing frame 239 onto the stack...
# Pushing frame 240 onto the stack...
# Pushing frame 241 onto the stack...
# Pushing frame 242 onto the stack...
# Pushing frame 243 onto the stack...
# Pushing frame 244 onto the stack...
# Pushing frame 245 onto the stack...
# Pushing frame 246 onto the stack...
# Pushing frame 247 onto the stack...
# Pushing frame 248 onto the stack...
# Pushing frame 249 onto the stack...
# Pushing frame 250 onto the stack...
# Pushing frame 251 onto the stack...
# Pushing frame 252 onto the stack...
# Pushing frame 253 onto the stack...
# Pushing frame 254 onto the stack...
# Pushing frame 255 onto the stack...
# Pushing frame 256 onto the stack...
# Pushing frame 257 onto the stack...
# Pushing frame 258 onto the stack...
# Pushing frame 259 onto the stack...
# Pushing frame 260 onto the stack...
# Pushing frame 261 onto the stack...
# Pushing frame 262 onto the stack...
# Pushing frame 263 onto the stack...
# Pushing frame 264 onto the stack...
# Pushing frame 265 onto the stack...
# Pushing frame 266 onto the stack...
# Pushing frame 267 onto the stack...
# Pushing frame 268 onto the stack...
# Pushing frame 269 onto the stack...
# Pushing frame 270 onto the stack...
# Pushing frame 271 onto the stack...
# Pushing frame 272 onto the stack...
# Pushing frame 273 onto the stack...
# Pushing frame 274 onto the stack...
# Pushing frame 275 onto the stack...
# Pushing frame 276 onto the stack...
# Pushing frame 277 onto the stack...
# Pushing frame 278 onto the stack...
# Pushing frame 279 onto the stack...
# Pushing frame 280 onto the stack...
# Pushing frame 281 onto the stack...
# Pushing frame 282 onto the stack...
# Pushing frame 283 onto the stack...
# Pushing frame 284 onto the stack...
# Pushing frame 285 onto the stack...
# Pushing frame 286 onto the stack...
# Pushing frame 287 onto the stack...
# Pushing frame 288 onto the stack...
# Pushing frame 289 onto the stack...
# Pushing frame 290 onto the stack...
# Pushing frame 291 onto the stack...
# Pushing frame 292 onto the stack...
# Pushing frame 293 onto the stack...
# Pushing frame 294 onto the stack...
# Pushing frame 295 onto the stack...
# Pushing frame 296 onto the stack...
# Pushing frame 297 onto the stack...
# Pushing frame 298 onto the stack...
# Pushing frame 299 onto the stack...
# Pushing frame 300 onto the stack...
# Pushing frame 301 onto the stack...
# Pushing frame 302 onto the stack...
# Pushing frame 303 onto the stack...
# Pushing frame 304 onto the stack...
# Pushing frame 305 onto the stack...
# Pushing frame 306 onto the stack...
# Pushing frame 307 onto the stack...
# Pushing frame 308 onto the stack...
# Pushing frame 309 onto the stack...
# Pushing frame 310 onto the stack...
# Pushing frame 311 onto the stack...
# Pushing frame 312 onto the stack...
# Pushing frame 313 onto the stack...
# Pushing frame 314 onto the stack...
# Pushing frame 315 onto the stack...
# Pushing frame 316 onto the stack...
# Pushing frame 317 onto the stack...
# Pushing frame 318 onto the stack...
# Pushing frame 319 onto the stack...
# Pushing frame 320 onto the stack...
# Pushing frame 321 onto the stack...
# Pushing frame 322 onto the stack...
# Pushing frame 323 onto the stack...
# Pushing frame 324 onto the stack...
# Pushing frame 325 onto the stack...
# Pushing frame 326 onto the stack...
# Pushing frame 327 onto the stack...
# Pushing frame 328 onto the stack...
# Pushing frame 329 onto the stack...
# Pushing frame 330 onto the stack...
# Pushing frame 331 onto the stack...
# Pushing frame 332 onto the stack...
# Pushing frame 333 onto the stack...
# Pushing frame 334 onto the stack...
# Pushing frame 335 onto the stack...
# Pushing frame 336 onto the stack...
# Pushing frame 337 onto the stack...
# Pushing frame 338 onto the stack...
# Pushing frame 339 onto the stack...
# Pushing frame 340 onto the stack...
# Pushing frame 341 onto the stack...
# Pushing frame 342 onto the stack...
# Pushing frame 343 onto the stack...
# Pushing frame 344 onto the stack...
# Pushing frame 345 onto the stack...
# Pushing frame 346 onto the stack...
# Pushing frame 347 onto the stack...
# Pushing frame 348 onto the stack...
# Pushing frame 349 onto the stack...
# Pushing frame 350 onto the stack...
# Pushing frame 351 onto the stack...
# Pushing frame 352 onto the stack...
# Pushing frame 353 onto the stack...
# Pushing frame 354 onto the stack...
# Pushing frame 355 onto the stack...
# Pushing frame 356 onto the stack...
# Pushing frame 357 onto the stack...
# Pushing frame 358 onto the stack...
# Pushing frame 359 onto the stack...
# Pushing frame 360 onto the stack...
# Pushing frame 361 onto the stack...
# Pushing frame 362 onto the stack...
# Pushing frame 363 onto the stack...
# Pushing frame 364 onto the stack...
# Pushing frame 365 onto the stack...
# Pushing frame 366 onto the stack...
# Pushing frame 367 onto the stack...
# Pushing frame 368 onto the stack...
# Pushing frame 369 onto the stack...
# Pushing frame 370 onto the stack...
# Pushing frame 371 onto the stack...
# Pushing frame 372 onto the stack...
# Pushing frame 373 onto the stack...
# Pushing frame 374 onto the stack...
# Pushing frame 375 onto the stack...
# Pushing frame 376 onto the stack...
# Pushing frame 377 onto the stack...
# Pushing frame 378 onto the stack...
# Pushing frame 379 onto the stack...
# Pushing frame 380 onto the stack...
# Pushing frame 381 onto the stack...
# Pushing frame 382 onto the stack...
# Pushing frame 383 onto the stack...
# Pushing frame 384 onto the stack...
# Pushing frame 385 onto the stack...
# Pushing frame 386 onto the stack...
# Pushing frame 387 onto the stack...
# Pushing frame 388 onto the stack...
# Pushing frame 389 onto the stack...
# Pushing frame 390 onto the stack...
# Pushing frame 391 onto the stack...
# Pushing frame 392 onto the stack...
# Pushing frame 393 onto the stack...
# Pushing frame 394 onto the stack...
# Pushing frame 395 onto the stack...
# Pushing frame 396 onto the stack...
# Pushing frame 397 onto the stack...
# Pushing frame 398 onto the stack...
# Pushing frame 399 onto the stack...
# Pushing frame 400 onto the stack...
# Pushing frame 401 onto the stack...
# Pushing frame 402 onto the stack...
# Pushing frame 403 onto the stack...
# Pushing frame 404 onto the stack...
# Pushing frame 405 onto the stack...
# Pushing frame 406 onto the stack...
# Pushing frame 407 onto the stack...
# Pushing frame 408 onto the stack...
# Pushing frame 409 onto the stack...
# Pushing frame 410 onto the stack...
# Pushing frame 411 onto the stack...
# Pushing frame 412 onto the stack...
# Pushing frame 413 onto the stack...
# Pushing frame 414 onto the stack...
# Pushing frame 415 onto the stack...
# Pushing frame 416 onto the stack...
# Pushing frame 417 onto the stack...
# Pushing frame 418 onto the stack...
# Pushing frame 419 onto the stack...
# Pushing frame 420 onto the stack...
# Pushing frame 421 onto the stack...
# Pushing frame 422 onto the stack...
# Pushing frame 423 onto the stack...
# Pushing frame 424 onto the stack...
# Pushing frame 425 onto the stack...
# Pushing frame 426 onto the stack...
# Pushing frame 427 onto the stack...
# Pushing frame 428 onto the stack...
# Pushing frame 429 onto the stack...
# Pushing frame 430 onto the stack...
# Pushing frame 431 onto the stack...
# Pushing frame 432 onto the stack...
# Pushing frame 433 onto the stack...
# Pushing frame 434 onto the stack...
# Pushing frame 435 onto the stack...
# Pushing frame 436 onto the stack...
# Pushing frame 437 onto the stack...
# Pushing frame 438 onto the stack...
# Pushing frame 439 onto the stack...
# Pushing frame 440 onto the stack...
# Pushing frame 441 onto the stack...
# Pushing frame 442 onto the stack...
# Pushing frame 443 onto the stack...
# Pushing frame 444 onto the stack...
# Pushing frame 445 onto the stack...
# Pushing frame 446 onto the stack...
# Pushing frame 447 onto the stack...
# Pushing frame 448 onto the stack...
# Pushing frame 449 onto the stack...
# Pushing frame 450 onto the stack...
# Pushing frame 451 onto the stack...
# Pushing frame 452 onto the stack...
# Pushing frame 453 onto the stack...
# Pushing frame 454 onto the stack...
# Pushing frame 455 onto the stack...
# Pushing frame 456 onto the stack...
# Pushing frame 457 onto the stack...
# Pushing frame 458 onto the stack...
# Pushing frame 459 onto the stack...
# Pushing frame 460 onto the stack...
# Pushing frame 461 onto the stack...
# Pushing frame 462 onto the stack...
# Pushing frame 463 onto the stack...
# Pushing frame 464 onto the stack...
# Pushing frame 465 onto the stack...
# Pushing frame 466 onto the stack...
# Pushing frame 467 onto the stack...
# Pushing frame 468 onto the stack...
# Pushing frame 469 onto the stack...
# Pushing frame 470 onto the stack...
# Pushing frame 471 onto the stack...
# Pushing frame 472 onto the stack...
# Pushing frame 473 onto the stack...
# Pushing frame 474 onto the stack...
# Pushing frame 475 onto the stack...
# Pushing frame 476 onto the stack...
# Pushing frame 477 onto the stack...
# Pushing frame 478 onto the stack...
# Pushing frame 479 onto the stack...
# Pushing frame 480 onto the stack...
# Pushing frame 481 onto the stack...
# Pushing frame 482 onto the stack...
# Pushing frame 483 onto the stack...
# Pushing frame 484 onto the stack...
# Pushing frame 485 onto the stack...
# Pushing frame 486 onto the stack...
# Pushing frame 487 onto the stack...
# Pushing frame 488 onto the stack...
# Pushing frame 489 onto the stack...
# Pushing frame 490 onto the stack...
# Pushing frame 491 onto the stack...
# Pushing frame 492 onto the stack...
# Pushing frame 493 onto the stack...
# Pushing frame 494 onto the stack...
# Pushing frame 495 onto the stack...
# Pushing frame 496 onto the stack...
# Pushing frame 497 onto the stack...
# Pushing frame 498 onto the stack...
# Pushing frame 499 onto the stack...
# Pushing frame 500 onto the stack...
# Pushing frame 501 onto the stack...
# Pushing frame 502 onto the stack...
# Pushing frame 503 onto the stack...
# Pushing frame 504 onto the stack...
# Pushing frame 505 onto the stack...
# Pushing frame 506 onto the stack...
# Pushing frame 507 onto the stack...
# Pushing frame 508 onto the stack...
# Pushing frame 509 onto the stack...
# Pushing frame 510 onto the stack...
# Pushing frame 511 onto the stack...
# Pushing frame 512 onto the stack...
# Pushing frame 513 onto the stack...
# Pushing frame 514 onto the stack...
# Pushing frame 515 onto the stack...
# Pushing frame 516 onto the stack...
# Pushing frame 517 onto the stack...
# Pushing frame 518 onto the stack...
# Pushing frame 519 onto the stack...
# Pushing frame 520 onto the stack...
# Pushing frame 521 onto the stack...
# Pushing frame 522 onto the stack...
# Pushing frame 523 onto the stack...
# Pushing frame 524 onto the stack...
# Pushing frame 525 onto the stack...
# Pushing frame 526 onto the stack...
# Pushing frame 527 onto the stack...
# Pushing frame 528 onto the stack...
# Pushing frame 529 onto the stack...
# Pushing frame 530 onto the stack...
# Pushing frame 531 onto the stack...
# Pushing frame 532 onto the stack...
# Pushing frame 533 onto the stack...
# Pushing frame 534 onto the stack...
# Pushing frame 535 onto the stack...
# Pushing frame 536 onto the stack...
# Pushing frame 537 onto the stack...
# Pushing frame 538 onto the stack...
# Pushing frame 539 onto the stack...
# Pushing frame 540 onto the stack...
# Pushing frame 541 onto the stack...
# Pushing frame 542 onto the stack...
# Pushing frame 543 onto the stack...
# Pushing frame 544 onto the stack...
# Pushing frame 545 onto the stack...
# Pushing frame 546 onto the stack...
# Pushing frame 547 onto the stack...
# Pushing frame 548 onto the stack...
# Pushing frame 549 onto the stack...
# Pushing frame 550 onto the stack...
# Pushing frame 551 onto the stack...
# Pushing frame 552 onto the stack...
# Pushing frame 553 onto the stack...
# Pushing frame 554 onto the stack...
# Pushing frame 555 onto the stack...
# Pushing frame 556 onto the stack...
# Pushing frame 557 onto the stack...
# Pushing frame 558 onto the stack...
# Pushing frame 559 onto the stack...
# Pushing frame 560 onto the stack...
# Pushing frame 561 onto the stack...
# Pushing frame 562 onto the stack...
# Pushing frame 563 onto the stack...
# Pushing frame 564 onto the stack...
# Pushing frame 565 onto the stack...
# Pushing frame 566 onto the stack...
# Pushing frame 567 onto the stack...
# Pushing frame 568 onto the stack...
# Pushing frame 569 onto the stack...
# Pushing frame 570 onto the stack...
# Pushing frame 571 onto the stack...
# Pushing frame 572 onto the stack...
# Pushing frame 573 onto the stack...
# Pushing frame 574 onto the stack...
# Pushing frame 575 onto the stack...
# Pushing frame 576 onto the stack...
# Pushing frame 577 onto the stack...
# Pushing frame 578 onto the stack...
# Pushing frame 579 onto the stack...
# Pushing frame 580 onto the stack...
# Pushing frame 581 onto the stack...
# Pushing frame 582 onto the stack...
# Pushing frame 583 onto the stack...
# Pushing frame 584 onto the stack...
# Pushing frame 585 onto the stack...
# Pushing frame 586 onto the stack...
# Pushing frame 587 onto the stack...
# Pushing frame 588 onto the stack...
# Pushing frame 589 onto the stack...
# Pushing frame 590 onto the stack...
# Pushing frame 591 onto the stack...
# Pushing frame 592 onto the stack...
# Pushing frame 593 onto the stack...
# Pushing frame 594 onto the stack...
# Pushing frame 595 onto the stack...
# Pushing frame 596 onto the stack...
# Pushing frame 597 onto the stack...
# Pushing frame 598 onto the stack...
# Pushing frame 599 onto the stack...
# Pushing frame 600 onto the stack...
# Pushing frame 601 onto the stack...
# Pushing frame 602 onto the stack...
# Pushing frame 603 onto the stack...
# Pushing frame 604 onto the stack...
# Pushing frame 605 onto the stack...
# Pushing frame 606 onto the stack...
# Pushing frame 607 onto the stack...
# Pushing frame 608 onto the stack...
# Pushing frame 609 onto the stack...
# Pushing frame 610 onto the stack...
# Pushing frame 611 onto the stack...
# Pushing frame 612 onto the stack...
# Pushing frame 613 onto the stack...
# Pushing frame 614 onto the stack...
# Pushing frame 615 onto the stack...
# Pushing frame 616 onto the stack...
# Pushing frame 617 onto the stack...
# Pushing frame 618 onto the stack...
# Pushing frame 619 onto the stack...
# Pushing frame 620 onto the stack...
# Pushing frame 621 onto the stack...
# Pushing frame 622 onto the stack...
# Pushing frame 623 onto the stack...
# Pushing frame 624 onto the stack...
# Pushing frame 625 onto the stack...
# Pushing frame 626 onto the stack...
# Pushing frame 627 onto the stack...
# Pushing frame 628 onto the stack...
# Pushing frame 629 onto the stack...
# Pushing frame 630 onto the stack...
# Pushing frame 631 onto the stack...
# Pushing frame 632 onto the stack...
# Pushing frame 633 onto the stack...
# Pushing frame 634 onto the stack...
# Pushing frame 635 onto the stack...
# Pushing frame 636 onto the stack...
# Pushing frame 637 onto the stack...
# Pushing frame 638 onto the stack...
# Pushing frame 639 onto the stack...
# Pushing frame 640 onto the stack...
# Pushing frame 641 onto the stack...
# Pushing frame 642 onto the stack...
# Pushing frame 643 onto the stack...
# Pushing frame 644 onto the stack...
# Pushing frame 645 onto the stack...
# Pushing frame 646 onto the stack...
# Pushing frame 647 onto the stack...
# Pushing frame 648 onto the stack...
# Pushing frame 649 onto the stack...
# Pushing frame 650 onto the stack...
# Pushing frame 651 onto the stack...
# Pushing frame 652 onto the stack...
# Pushing frame 653 onto the stack...
# Pushing frame 654 onto the stack...
# Pushing frame 655 onto the stack...
# Pushing frame 656 onto the stack...
# Pushing frame 657 onto the stack...
# Pushing frame 658 onto the stack...
# Pushing frame 659 onto the stack...
# Pushing frame 660 onto the stack...
# Pushing frame 661 onto the stack...
# Pushing frame 662 onto the stack...
# Pushing frame 663 onto the stack...
# Pushing frame 664 onto the stack...
# Pushing frame 665 onto the stack...
# Pushing frame 666 onto the stack...
# Pushing frame 667 onto the stack...
# Pushing frame 668 onto the stack...
# Pushing frame 669 onto the stack...
# Pushing frame 670 onto the stack...
# Pushing frame 671 onto the stack...
# Pushing frame 672 onto the stack...
# Pushing frame 673 onto the stack...
# Pushing frame 674 onto the stack...
# Pushing frame 675 onto the stack...
# Pushing frame 676 onto the stack...
# Pushing frame 677 onto the stack...
# Pushing frame 678 onto the stack...
# Pushing frame 679 onto the stack...
# Pushing frame 680 onto the stack...
# Pushing frame 681 onto the stack...
# Pushing frame 682 onto the stack...
# Pushing frame 683 onto the stack...
# Pushing frame 684 onto the stack...
# Pushing frame 685 onto the stack...
# Pushing frame 686 onto the stack...
# Pushing frame 687 onto the stack...
# Pushing frame 688 onto the stack...
# Pushing frame 689 onto the stack...
# Pushing frame 690 onto the stack...
# Pushing frame 691 onto the stack...
# Pushing frame 692 onto the stack...
# Pushing frame 693 onto the stack...
# Pushing frame 694 onto the stack...
# Pushing frame 695 onto the stack...
# Pushing frame 696 onto the stack...
# Pushing frame 697 onto the stack...
# Pushing frame 698 onto the stack...
# Pushing frame 699 onto the stack...
# Pushing frame 700 onto the stack...
# Pushing frame 701 onto the stack...
# Pushing frame 702 onto the stack...
# Pushing frame 703 onto the stack...
# Pushing frame 704 onto the stack...
# Pushing frame 705 onto the stack...
# Pushing frame 706 onto the stack...
# Pushing frame 707 onto the stack...
# Pushing frame 708 onto the stack...
# Pushing frame 709 onto the stack...
# Pushing frame 710 onto the stack...
# Pushing frame 711 onto the stack...
# Pushing frame 712 onto the stack...
# Pushing frame 713 onto the stack...
# Pushing frame 714 onto the stack...
# Pushing frame 715 onto the stack...
# Pushing frame 716 onto the stack...
# Pushing frame 717 onto the stack...
# Pushing frame 718 onto the stack...
# Pushing frame 719 onto the stack...
# Pushing frame 720 onto the stack...
# Pushing frame 721 onto the stack...
# Pushing frame 722 onto the stack...
# Pushing frame 723 onto the stack...
# Pushing frame 724 onto the stack...
# Pushing frame 725 onto the stack...
# Pushing frame 726 onto the stack...
# Pushing frame 727 onto the stack...
# Pushing frame 728 onto the stack...
# Pushing frame 729 onto the stack...
# Pushing frame 730 onto the stack...
# Pushing frame 731 onto the stack...
# Pushing frame 732 onto the stack...
# Pushing frame 733 onto the stack...
# Pushing frame 734 onto the stack...
# Pushing frame 735 onto the stack...
# Pushing frame 736 onto the stack...
# Pushing frame 737 onto the stack...
# Pushing frame 738 onto the stack...
# Pushing frame 739 onto the stack...
# Pushing frame 740 onto the stack...
# Pushing frame 741 onto the stack...
# Pushing frame 742 onto the stack...
# Pushing frame 743 onto the stack...
# Pushing frame 744 onto the stack...
# Pushing frame 745 onto the stack...
# Pushing frame 746 onto the stack...
# Pushing frame 747 onto the stack...
# Pushing frame 748 onto the stack...
# Pushing frame 749 onto the stack...
# Pushing frame 750 onto the stack...
# Pushing frame 751 onto the stack...
# Pushing frame 752 onto the stack...
# Pushing frame 753 onto the stack...
# Pushing frame 754 onto the stack...
# Pushing frame 755 onto the stack...
# Pushing frame 756 onto the stack...
# Pushing frame 757 onto the stack...
# Pushing frame 758 onto the stack...
# Pushing frame 759 onto the stack...
# Pushing frame 760 onto the stack...
# Pushing frame 761 onto the stack...
# Pushing frame 762 onto the stack...
# Pushing frame 763 onto the stack...
# Pushing frame 764 onto the stack...
# Pushing frame 765 onto the stack...
# Pushing frame 766 onto the stack...
# Pushing frame 767 onto the stack...
# Pushing frame 768 onto the stack...
# Pushing frame 769 onto the stack...
# Pushing frame 770 onto the stack...
# Pushing frame 771 onto the stack...
# Pushing frame 772 onto the stack...
# Pushing frame 773 onto the stack...
# Pushing frame 774 onto the stack...
# Pushing frame 775 onto the stack...
# Pushing frame 776 onto the stack...
# Pushing frame 777 onto the stack...
# Pushing frame 778 onto the stack...
# Pushing frame 779 onto the stack...
# Pushing frame 780 onto the stack...
# Pushing frame 781 onto the stack...
# Pushing frame 782 onto the stack...
# Pushing frame 783 onto the stack...
# Pushing frame 784 onto the stack...
# Pushing frame 785 onto the stack...
# Pushing frame 786 onto the stack...
# Pushing frame 787 onto the stack...
# Pushing frame 788 onto the stack...
# Pushing frame 789 onto the stack...
# Pushing frame 790 onto the stack...
# Pushing frame 791 onto the stack...
# Pushing frame 792 onto the stack...
# Pushing frame 793 onto the stack...
# Pushing frame 794 onto the stack...
# Pushing frame 795 onto the stack...
# Pushing frame 796 onto the stack...
# Pushing frame 797 onto the stack...
# Pushing frame 798 onto the stack...
# Pushing frame 799 onto the stack...
# Pushing frame 800 onto the stack...
# Pushing frame 801 onto the stack...
# Pushing frame 802 onto the stack...
# Pushing frame 803 onto the stack...
# Pushing frame 804 onto the stack...
# Pushing frame 805 onto the stack...
# Pushing frame 806 onto the stack...
# Pushing frame 807 onto the stack...
# Pushing frame 808 onto the stack...
# Pushing frame 809 onto the stack...
# Pushing frame 810 onto the stack...
# Pushing frame 811 onto the stack...
# Pushing frame 812 onto the stack...
# Pushing frame 813 onto the stack...
# Pushing frame 814 onto the stack...
# Pushing frame 815 onto the stack...
# Pushing frame 816 onto the stack...
# Pushing frame 817 onto the stack...
# Pushing frame 818 onto the stack...
# Pushing frame 819 onto the stack...
# Pushing frame 820 onto the stack...
# Pushing frame 821 onto the stack...
# Pushing frame 822 onto the stack...
# Pushing frame 823 onto the stack...
# Pushing frame 824 onto the stack...
# Pushing frame 825 onto the stack...
# Pushing frame 826 onto the stack...
# Pushing frame 827 onto the stack...
# Pushing frame 828 onto the stack...
# Pushing frame 829 onto the stack...
# Pushing frame 830 onto the stack...
# Pushing frame 831 onto the stack...
# Pushing frame 832 onto the stack...
# Pushing frame 833 onto the stack...
# Pushing frame 834 onto the stack...
# Pushing frame 835 onto the stack...
# Pushing frame 836 onto the stack...
# Pushing frame 837 onto the stack...
# Pushing frame 838 onto the stack...
# Pushing frame 839 onto the stack...
# Pushing frame 840 onto the stack...
# Pushing frame 841 onto the stack...
# Pushing frame 842 onto the stack...
# Pushing frame 843 onto the stack...
# Pushing frame 844 onto the stack...
# Pushing frame 845 onto the stack...
# Pushing frame 846 onto the stack...
# Pushing frame 847 onto the stack...
# Pushing frame 848 onto the stack...
# Pushing frame 849 onto the stack...
# Pushing frame 850 onto the stack...
# Pushing frame 851 onto the stack...
# Pushing frame 852 onto the stack...
# Pushing frame 853 onto the stack...
# Pushing frame 854 onto the stack...
# Pushing frame 855 onto the stack...
# Pushing frame 856 onto the stack...
# Pushing frame 857 onto the stack...
# Pushing frame 858 onto the stack...
# Pushing frame 859 onto the stack...
# Pushing frame 860 onto the stack...
# Pushing frame 861 onto the stack...
# Pushing frame 862 onto the stack...
# Pushing frame 863 onto the stack...
# Pushing frame 864 onto the stack...
# Pushing frame 865 onto the stack...
# Pushing frame 866 onto the stack...
# Pushing frame 867 onto the stack...
# Pushing frame 868 onto the stack...
# Pushing frame 869 onto the stack...
# Pushing frame 870 onto the stack...
# Pushing frame 871 onto the stack...
# Pushing frame 872 onto the stack...
# Pushing frame 873 onto the stack...
# Pushing frame 874 onto the stack...
# Pushing frame 875 onto the stack...
# Pushing frame 876 onto the stack...
# Pushing frame 877 onto the stack...
# Pushing frame 878 onto the stack...
# Pushing frame 879 onto the stack...
# Pushing frame 880 onto the stack...
# Pushing frame 881 onto the stack...
# Pushing frame 882 onto the stack...
# Pushing frame 883 onto the stack...
# Pushing frame 884 onto the stack...
# Pushing frame 885 onto the stack...
# Pushing frame 886 onto the stack...
# Pushing frame 887 onto the stack...
# Pushing frame 888 onto the stack...
# Pushing frame 889 onto the stack...
# Pushing frame 890 onto the stack...
# Pushing frame 891 onto the stack...
# Pushing frame 892 onto the stack...
# Pushing frame 893 onto the stack...
# Pushing frame 894 onto the stack...
# Pushing frame 895 onto the stack...
# Pushing frame 896 onto the stack...
# Pushing frame 897 onto the stack...
# Pushing frame 898 onto the stack...
# Pushing frame 899 onto the stack...
# Pushing frame 900 onto the stack...
# Pushing frame 901 onto the stack...
# Pushing frame 902 onto the stack...
# Pushing frame 903 onto the stack...
# Pushing frame 904 onto the stack...
# Pushing frame 905 onto the stack...
# Pushing frame 906 onto the stack...
# Pushing frame 907 onto the stack...
# Pushing frame 908 onto the stack...
# Pushing frame 909 onto the stack...
# Pushing frame 910 onto the stack...
# Pushing frame 911 onto the stack...
# Pushing frame 912 onto the stack...
# Pushing frame 913 onto the stack...
# Pushing frame 914 onto the stack...
# Pushing frame 915 onto the stack...
# Pushing frame 916 onto the stack...
# Pushing frame 917 onto the stack...
# Pushing frame 918 onto the stack...
# Pushing frame 919 onto the stack...
# Pushing frame 920 onto the stack...
# Pushing frame 921 onto the stack...
# Pushing frame 922 onto the stack...
# Pushing frame 923 onto the stack...
# Pushing frame 924 onto the stack...
# Pushing frame 925 onto the stack...
# Pushing frame 926 onto the stack...
# Pushing frame 927 onto the stack...
# Pushing frame 928 onto the stack...
# Pushing frame 929 onto the stack...
# Pushing frame 930 onto the stack...
# Pushing frame 931 onto the stack...
# Pushing frame 932 onto the stack...
# Pushing frame 933 onto the stack...
# Pushing frame 934 onto the stack...
# Pushing frame 935 onto the stack...
# Pushing frame 936 onto the stack...
# Pushing frame 937 onto the stack...
# Pushing frame 938 onto the stack...
# Pushing frame 939 onto the stack...
# Pushing frame 940 onto the stack...
# Pushing frame 941 onto the stack...
# Pushing frame 942 onto the stack...
# Pushing frame 943 onto the stack...
# Pushing frame 944 onto the stack...
# Pushing frame 945 onto the stack...
# Pushing frame 946 onto the stack...
# Pushing frame 947 onto the stack...
# Pushing frame 948 onto the stack...
# Pushing frame 949 onto the stack...
# Pushing frame 950 onto the stack...
# Pushing frame 951 onto the stack...
# Pushing frame 952 onto the stack...
# Pushing frame 953 onto the stack...
# Pushing frame 954 onto the stack...
# Pushing frame 955 onto the stack...
# Pushing frame 956 onto the stack...
# Pushing frame 957 onto the stack...
# Pushing frame 958 onto the stack...
# Pushing frame 959 onto the stack...
# Pushing frame 960 onto the stack...
# Pushing frame 961 onto the stack...
# Pushing frame 962 onto the stack...
# Pushing frame 963 onto the stack...
# Pushing frame 964 onto the stack...
# Pushing frame 965 onto the stack...
# Pushing frame 966 onto the stack...
# Pushing frame 967 onto the stack...
# Pushing frame 968 onto the stack...
# Pushing frame 969 onto the stack...
# Pushing frame 970 onto the stack...
# Pushing frame 971 onto the stack...
# Pushing frame 972 onto the stack...
# Pushing frame 973 onto the stack...
# Pushing frame 974 onto the stack...
# Pushing frame 975 onto the stack...
# Pushing frame 976 onto the stack...
# Pushing frame 977 onto the stack...
# Pushing frame 978 onto the stack...
# Pushing frame 979 onto the stack...
# Pushing frame 980 onto the stack...
# Pushing frame 981 onto the stack...
# Pushing frame 982 onto the stack...
# Pushing frame 983 onto the stack...
# Pushing frame 984 onto the stack...
# Pushing frame 985 onto the stack...
# Pushing frame 986 onto the stack...
# Pushing frame 987 onto the stack...
# Pushing frame 988 onto the stack...
# Pushing frame 989 onto the stack...
# Pushing frame 990 onto the stack...
# Pushing frame 991 onto the stack...
# Pushing frame 992 onto the stack...
# Pushing frame 993 onto the stack...
# Pushing frame 994 onto the stack...
# Pushing frame 995 onto the stack...
# Pushing frame 996 onto the stack...
# Pushing frame 997 onto the stack...
# Pushing frame 998 onto the stack...
# Pushing frame 999 onto the stack...
# Pushing frame 1000 onto the stack...
# Pushing frame 1001 onto the stack...
# Pushing frame 1002 onto the stack...
# Pushing frame 1003 onto the stack...
# Pushing frame 1004 onto the stack...
# Pushing frame 1005 onto the stack...
# Pushing frame 1006 onto the stack...
# Pushing frame 1007 onto the stack...
# Pushing frame 1008 onto the stack...
# Pushing frame 1009 onto the stack...
# Pushing frame 1010 onto the stack...
# Pushing frame 1011 onto the stack...
# Pushing frame 1012 onto the stack...
# Pushing frame 1013 onto the stack...
# Pushing frame 1014 onto the stack...
# Pushing frame 1015 onto the stack...
# Pushing frame 1016 onto the stack...
# Pushing frame 1017 onto the stack...
# Pushing frame 1018 onto the stack...
# Pushing frame 1019 onto the stack...
# Pushing frame 1020 onto the stack...
# Pushing frame 1021 onto the stack...
# Pushing frame 1022 onto the stack...
# Pushing frame 1023 onto the stack...
# Pushing frame 1024 onto the stack...
# Pushing frame 1025 onto the stack...
# Pushing frame 1026 onto the stack...
# Pushing frame 1027 onto the stack...
# Pushing frame 1028 onto the stack...
# Pushing frame 1029 onto the stack...
# Pushing frame 1030 onto the stack...
# Pushing frame 1031 onto the stack...
# Pushing frame 1032 onto the stack...
# Pushing frame 1033 onto the stack...
# Pushing frame 1034 onto the stack...
# Pushing frame 1035 onto the stack...
# Pushing frame 1036 onto the stack...
# Pushing frame 1037 onto the stack...
# Pushing frame 1038 onto the stack...
# Pushing frame 1039 onto the stack...
# Pushing frame 1040 onto the stack...
# Pushing frame 1041 onto the stack...
# Pushing frame 1042 onto the stack...
# Pushing frame 1043 onto the stack...
# Pushing frame 1044 onto the stack...
# Pushing frame 1045 onto the stack...
# Pushing frame 1046 onto the stack...
# Pushing frame 1047 onto the stack...
# Pushing frame 1048 onto the stack...
# Pushing frame 1049 onto the stack...
# Pushing frame 1050 onto the stack...
# Pushing frame 1051 onto the stack...
# Pushing frame 1052 onto the stack...
# Pushing frame 1053 onto the stack...
# Pushing frame 1054 onto the stack...
# Pushing frame 1055 onto the stack...
# Pushing frame 1056 onto the stack...
# Pushing frame 1057 onto the stack...
# Pushing frame 1058 onto the stack...
# Pushing frame 1059 onto the stack...
# Pushing frame 1060 onto the stack...
# Pushing frame 1061 onto the stack...
# Pushing frame 1062 onto the stack...
# Pushing frame 1063 onto the stack...
# Pushing frame 1064 onto the stack...
# Pushing frame 1065 onto the stack...
# Pushing frame 1066 onto the stack...
# Pushing frame 1067 onto the stack...
# Pushing frame 1068 onto the stack...
# Pushing frame 1069 onto the stack...
# Pushing frame 1070 onto the stack...
# Pushing frame 1071 onto the stack...
# Pushing frame 1072 onto the stack...
# Pushing frame 1073 onto the stack...
# Pushing frame 1074 onto the stack...
# Pushing frame 1075 onto the stack...
# Pushing frame 1076 onto the stack...
# Pushing frame 1077 onto the stack...
# Pushing frame 1078 onto the stack...
# Pushing frame 1079 onto the stack...
# Pushing frame 1080 onto the stack...
# Pushing frame 1081 onto the stack...
# Pushing frame 1082 onto the stack...
# Pushing frame 1083 onto the stack...
# Pushing frame 1084 onto the stack...
# Pushing frame 1085 onto the stack...
# Pushing frame 1086 onto the stack...
# Pushing frame 1087 onto the stack...
# Pushing frame 1088 onto the stack...
# Pushing frame 1089 onto the stack...
# Pushing frame 1090 onto the stack...
# Pushing frame 1091 onto the stack...
# Pushing frame 1092 onto the stack...
# Pushing frame 1093 onto the stack...
# Pushing frame 1094 onto the stack...
# Pushing frame 1095 onto the stack...
# Pushing frame 1096 onto the stack...
# Pushing frame 1097 onto the stack...
# Pushing frame 1098 onto the stack...
# Pushing frame 1099 onto the stack...
# Pushing frame 1100 onto the stack...
# Pushing frame 1101 onto the stack...
# Pushing frame 1102 onto the stack...
# Pushing frame 1103 onto the stack...
# Pushing frame 1104 onto the stack...
# Pushing frame 1105 onto the stack...
# Pushing frame 1106 onto the stack...
# Pushing frame 1107 onto the stack...
# Pushing frame 1108 onto the stack...
# Pushing frame 1109 onto the stack...
# Pushing frame 1110 onto the stack...
# Pushing frame 1111 onto the stack...
# Pushing frame 1112 onto the stack...
# Pushing frame 1113 onto the stack...
# Pushing frame 1114 onto the stack...
# Pushing frame 1115 onto the stack...
# Pushing frame 1116 onto the stack...
# Pushing frame 1117 onto the stack...
# Pushing frame 1118 onto the stack...
# Pushing frame 1119 onto the stack...
# Pushing frame 1120 onto the stack...
# Pushing frame 1121 onto the stack...
# Pushing frame 1122 onto the stack...
# Pushing frame 1123 onto the stack...
# Pushing frame 1124 onto the stack...
# Pushing frame 1125 onto the stack...
# Pushing frame 1126 onto the stack...
# Pushing frame 1127 onto the stack...
# Pushing frame 1128 onto the stack...
# Pushing frame 1129 onto the stack...
# Pushing frame 1130 onto the stack...
# Pushing frame 1131 onto the stack...
# Pushing frame 1132 onto the stack...
# Pushing frame 1133 onto the stack...
# Pushing frame 1134 onto the stack...
# Pushing frame 1135 onto the stack...
# Pushing frame 1136 onto the stack...
# Pushing frame 1137 onto the stack...
# Pushing frame 1138 onto the stack...
# Pushing frame 1139 onto the stack...
# Pushing frame 1140 onto the stack...
# Pushing frame 1141 onto the stack...
# Pushing frame 1142 onto the stack...
# Pushing frame 1143 onto the stack...
# Pushing frame 1144 onto the stack...
# Pushing frame 1145 onto the stack...
# Pushing frame 1146 onto the stack...
# Pushing frame 1147 onto the stack...
# Pushing frame 1148 onto the stack...
# Pushing frame 1149 onto the stack...
# Pushing frame 1150 onto the stack...
# Pushing frame 1151 onto the stack...
# Pushing frame 1152 onto the stack...
# Pushing frame 1153 onto the stack...
# Pushing frame 1154 onto the stack...
# Pushing frame 1155 onto the stack...
# Pushing frame 1156 onto the stack...
# Pushing frame 1157 onto the stack...
# Pushing frame 1158 onto the stack...
# Pushing frame 1159 onto the stack...
# Pushing frame 1160 onto the stack...
# Pushing frame 1161 onto the stack...
# Pushing frame 1162 onto the stack...
# Pushing frame 1163 onto the stack...
# Pushing frame 1164 onto the stack...
# Pushing frame 1165 onto the stack...
# Pushing frame 1166 onto the stack...
# Pushing frame 1167 onto the stack...
# Pushing frame 1168 onto the stack...
# Pushing frame 1169 onto the stack...
# Pushing frame 1170 onto the stack...
# Pushing frame 1171 onto the stack...
# Pushing frame 1172 onto the stack...
# Pushing frame 1173 onto the stack...
# Pushing frame 1174 onto the stack...
# Pushing frame 1175 onto the stack...
# Pushing frame 1176 onto the stack...
# Pushing frame 1177 onto the stack...
# Pushing frame 1178 onto the stack...
# Pushing frame 1179 onto the stack...
# Pushing frame 1180 onto the stack...
# Pushing frame 1181 onto the stack...
# Pushing frame 1182 onto the stack...
# Pushing frame 1183 onto the stack...
# Pushing frame 1184 onto the stack...
# Pushing frame 1185 onto the stack...
# Pushing frame 1186 onto the stack...
# Pushing frame 1187 onto the stack...
# Pushing frame 1188 onto the stack...
# Pushing frame 1189 onto the stack...
# Pushing frame 1190 onto the stack...
# Pushing frame 1191 onto the stack...
# Pushing frame 1192 onto the stack...
# Pushing frame 1193 onto the stack...
# Pushing frame 1194 onto the stack...
# Pushing frame 1195 onto the stack...
# Pushing frame 1196 onto the stack...
# Pushing frame 1197 onto the stack...
# Pushing frame 1198 onto the stack...
# Pushing frame 1199 onto the stack...
# Pushing frame 1200 onto the stack...
# Pushing frame 1201 onto the stack...
# Pushing frame 1202 onto the stack...
# Pushing frame 1203 onto the stack...
# Pushing frame 1204 onto the stack...
# Pushing frame 1205 onto the stack...
# Pushing frame 1206 onto the stack...
# Pushing frame 1207 onto the stack...
# Pushing frame 1208 onto the stack...
# Pushing frame 1209 onto the stack...
# Pushing frame 1210 onto the stack...
# Pushing frame 1211 onto the stack...
# Pushing frame 1212 onto the stack...
# Pushing frame 1213 onto the stack...
# Pushing frame 1214 onto the stack...
# Pushing frame 1215 onto the stack...
# Pushing frame 1216 onto the stack...
# Pushing frame 1217 onto the stack...
# Pushing frame 1218 onto the stack...
# Pushing frame 1219 onto the stack...
# Pushing frame 1220 onto the stack...
# Pushing frame 1221 onto the stack...
# Pushing frame 1222 onto the stack...
# Pushing frame 1223 onto the stack...
# Pushing frame 1224 onto the stack...
# Pushing frame 1225 onto the stack...
# Pushing frame 1226 onto the stack...
# Pushing frame 1227 onto the stack...
# Pushing frame 1228 onto the stack...
# Pushing frame 1229 onto the stack...
# Pushing frame 1230 onto the stack...
# Pushing frame 1231 onto the stack...
# Pushing frame 1232 onto the stack...
# Pushing frame 1233 onto the stack...
# Pushing frame 1234 onto the stack...
# Pushing frame 1235 onto the stack...
# Pushing frame 1236 onto the stack...
# Pushing frame 1237 onto the stack...
# Pushing frame 1238 onto the stack...
# Pushing frame 1239 onto the stack...
# Pushing frame 1240 onto the stack...
# Pushing frame 1241 onto the stack...
# Pushing frame 1242 onto the stack...
# Pushing frame 1243 onto the stack...
# Pushing frame 1244 onto the stack...
# Pushing frame 1245 onto the stack...
# Pushing frame 1246 onto the stack...
# Pushing frame 1247 onto the stack...
# Pushing frame 1248 onto the stack...
# Pushing frame 1249 onto the stack...
# Pushing frame 1250 onto the stack...
# Pushing frame 1251 onto the stack...
# Pushing frame 1252 onto the stack...
# Pushing frame 1253 onto the stack...
# Pushing frame 1254 onto the stack...
# Pushing frame 1255 onto the stack...
# Pushing frame 1256 onto the stack...
# Pushing frame 1257 onto the stack...
# Pushing frame 1258 onto the stack...
# Pushing frame 1259 onto the stack...
# Pushing frame 1260 onto the stack...
# Pushing frame 1261 onto the stack...
# Pushing frame 1262 onto the stack...
# Pushing frame 1263 onto the stack...
# Pushing frame 1264 onto the stack...
# Pushing frame 1265 onto the stack...
# Pushing frame 1266 onto the stack...
# Pushing frame 1267 onto the stack...
# Pushing frame 1268 onto the stack...
# Pushing frame 1269 onto the stack...
# Pushing frame 1270 onto the stack...
# Pushing frame 1271 onto the stack...
# Pushing frame 1272 onto the stack...
# Pushing frame 1273 onto the stack...
# Pushing frame 1274 onto the stack...
# Pushing frame 1275 onto the stack...
# Pushing frame 1276 onto the stack...
# Pushing frame 1277 onto the stack...
# Pushing frame 1278 onto the stack...
# Pushing frame 1279 onto the stack...
# Pushing frame 1280 onto the stack...
# Pushing frame 1281 onto the stack...
# Pushing frame 1282 onto the stack...
# Pushing frame 1283 onto the stack...
# Pushing frame 1284 onto the stack...
# Pushing frame 1285 onto the stack...
# Pushing frame 1286 onto the stack...
# Pushing frame 1287 onto the stack...
# Pushing frame 1288 onto the stack...
# Pushing frame 1289 onto the stack...
# Pushing frame 1290 onto the stack...
# Pushing frame 1291 onto the stack...
# Pushing frame 1292 onto the stack...
# Pushing frame 1293 onto the stack...
# Pushing frame 1294 onto the stack...
# Pushing frame 1295 onto the stack...
# Pushing frame 1296 onto the stack...
# Pushing frame 1297 onto the stack...
# Pushing frame 1298 onto the stack...
# Pushing frame 1299 onto the stack...
# Pushing frame 1300 onto the stack...
# Pushing frame 1301 onto the stack...
# Pushing frame 1302 onto the stack...
# Pushing frame 1303 onto the stack...
# Pushing frame 1304 onto the stack...
# Pushing frame 1305 onto the stack...
# Pushing frame 1306 onto the stack...
# Pushing frame 1307 onto the stack...
# Pushing frame 1308 onto the stack...
# Pushing frame 1309 onto the stack...
# Pushing frame 1310 onto the stack...
# Pushing frame 1311 onto the stack...
# Pushing frame 1312 onto the stack...
# Pushing frame 1313 onto the stack...
# Pushing frame 1314 onto the stack...
# Pushing frame 1315 onto the stack...
# Pushing frame 1316 onto the stack...
# Pushing frame 1317 onto the stack...
# Pushing frame 1318 onto the stack...
# Pushing frame 1319 onto the stack...
# Pushing frame 1320 onto the stack...
# Pushing frame 1321 onto the stack...
# Pushing frame 1322 onto the stack...
# Pushing frame 1323 onto the stack...
# Pushing frame 1324 onto the stack...
# Pushing frame 1325 onto the stack...
# Pushing frame 1326 onto the stack...
# Pushing frame 1327 onto the stack...
# ...
# Pushing frame 2596 onto the stack...
# Pushing frame 2597 onto the stack...
# Pushing frame 2598 onto the stack...
# Pushing frame 2599 onto the stack...
# Pushing frame 2600 onto the stack...
# Pushing frame 2601 onto the stack...
# Pushing frame 2602 onto the stack...
# Pushing frame 2603 onto the stack...
# Pushing frame 2604 onto the stack...
# Pushing frame 2605 onto the stack...
# Pushing frame 2606 onto the stack...
# Pushing frame 2607 onto the stack...
# Pushing frame 2608 onto the stack...
# Pushing frame 2609 onto the stack...
# Pushing frame 2610 onto the stack...
# Pushing frame 2611 onto the stack...
# Pushing frame 2612 onto the stack...
# Pushing frame 2613 onto the stack...
# Pushing frame 2614 onto the stack...
# Pushing frame 2615 onto the stack...
# Pushing frame 2616 onto the stack...
# Pushing frame 2617 onto the stack...
# Pushing frame 2618 onto the stack...
# Pushing frame 2619 onto the stack...
# Pushing frame 2620 onto the stack...
# Pushing frame 2621 onto the stack...
# Pushing frame 2622 onto the stack...
# Pushing frame 2623 onto the stack...
# Pushing frame 2624 onto the stack...
# Pushing frame 2625 onto the stack...
# Pushing frame 2626 onto the stack...
# Pushing frame 2627 onto the stack...
# Pushing frame 2628 onto the stack...
# Pushing frame 2629 onto the stack...
# Pushing frame 2630 onto the stack...
# Pushing frame 2631 onto the stack...
# Pushing frame 2632 onto the stack...
# Pushing frame 2633 onto the stack...
# Pushing frame 2634 onto the stack...
# Pushing frame 2635 onto the stack...
# Pushing frame 2636 onto the stack...
# Pushing frame 2637 onto the stack...
# Pushing frame 2638 onto the stack...
# Pushing frame 2639 onto the stack...
# Pushing frame 2640 onto the stack...
# Pushing frame 2641 onto the stack...
# Pushing frame 2642 onto the stack...
# Pushing frame 2643 onto the stack...
# Pushing frame 2644 onto the stack...
# Pushing frame 2645 onto the stack...
# Pushing frame 2646 onto the stack...
# Pushing frame 2647 onto the stack...
# Pushing frame 2648 onto the stack...
# Pushing frame 2649 onto the stack...
# Pushing frame 2650 onto the stack...
# Pushing frame 2651 onto the stack...
# Pushing frame 2652 onto the stack...
# Pushing frame 2653 onto the stack...
# Pushing frame 2654 onto the stack...
# Pushing frame 2655 onto the stack...
# Pushing frame 2656 onto the stack...
# Pushing frame 2657 onto the stack...
# Pushing frame 2658 onto the stack...
# Pushing frame 2659 onto the stack...
# Pushing frame 2660 onto the stack...
# Pushing frame 2661 onto the stack...
# Pushing frame 2662 onto the stack...
# Pushing frame 2663 onto the stack...
# Pushing frame 2664 onto the stack...
# Pushing frame 2665 onto the stack...
# Pushing frame 2666 onto the stack...
# Pushing frame 2667 onto the stack...
# Pushing frame 2668 onto the stack...
# Pushing frame 2669 onto the stack...
# Pushing frame 2670 onto the stack...
# Pushing frame 2671 onto the stack...
# Pushing frame 2672 onto the stack...
# Pushing frame 2673 onto the stack...
# Pushing frame 2674 onto the stack...
# Pushing frame 2675 onto the stack...
# Pushing frame 2676 onto the stack...
# Pushing frame 2677 onto the stack...
# Pushing frame 2678 onto the stack...
# Pushing frame 2679 onto the stack...
# Pushing frame 2680 onto the stack...
# Pushing frame 2681 onto the stack...
# Pushing frame 2682 onto the stack...
# Pushing frame 2683 onto the stack...
# Pushing frame 2684 onto the stack...
# Pushing frame 2685 onto the stack...
# Pushing frame 2686 onto the stack...
# Pushing frame 2687 onto the stack...
# Pushing frame 2688 onto the stack...
# Pushing frame 2689 onto the stack...
# Pushing frame 2690 onto the stack...
# Pushing frame 2691 onto the stack...
# Pushing frame 2692 onto the stack...
# Pushing frame 2693 onto the stack...
# Pushing frame 2694 onto the stack...
# Pushing frame 2695 onto the stack...
# Pushing frame 2696 onto the stack...
# Pushing frame 2697 onto the stack...
# Pushing frame 2698 onto the stack...
# Pushing frame 2699 onto the stack...
# Pushing frame 2700 onto the stack...
# Pushing frame 2701 onto the stack...
# Pushing frame 2702 onto the stack...
# Pushing frame 2703 onto the stack...
# Pushing frame 2704 onto the stack...
# Pushing frame 2705 onto the stack...
# Pushing frame 2706 onto the stack...
# Pushing frame 2707 onto the stack...
# Pushing frame 2708 onto the stack...
# Pushing frame 2709 onto the stack...
# Pushing frame 2710 onto the stack...
# Pushing frame 2711 onto the stack...
# Pushing frame 2712 onto the stack...
# Pushing frame 2713 onto the stack...
# Pushing frame 2714 onto the stack...
# Pushing frame 2715 onto the stack...
# Pushing frame 2716 onto the stack...
# Pushing frame 2717 onto the stack...
# Pushing frame 2718 onto the stack...
# Pushing frame 2719 onto the stack...
# Pushing frame 2720 onto the stack...
# Pushing frame 2721 onto the stack...
# Pushing frame 2722 onto the stack...
# Pushing frame 2723 onto the stack...
# Pushing frame 2724 onto the stack...
# Pushing frame 2725 onto the stack...
# Pushing frame 2726 onto the stack...
# Pushing frame 2727 onto the stack...
# Pushing frame 2728 onto the stack...
# Pushing frame 2729 onto the stack...
# Pushing frame 2730 onto the stack...
# Pushing frame 2731 onto the stack...
# Pushing frame 2732 onto the stack...
# Pushing frame 2733 onto the stack...
# Pushing frame 2734 onto the stack...
# Pushing frame 2735 onto the stack...
# Pushing frame 2736 onto the stack...
# Pushing frame 2737 onto the stack...
# Pushing frame 2738 onto the stack...
# Pushing frame 2739 onto the stack...
# Pushing frame 2740 onto the stack...
# Pushing frame 2741 onto the stack...
# Pushing frame 2742 onto the stack...
# Pushing frame 2743 onto the stack...
# Pushing frame 2744 onto the stack...
# Pushing frame 2745 onto the stack...
# Pushing frame 2746 onto the stack...
# Pushing frame 2747 onto the stack...
# Pushing frame 2748 onto the stack...
# Pushing frame 2749 onto the stack...
# Pushing frame 2750 onto the stack...
# Pushing frame 2751 onto the stack...
# Pushing frame 2752 onto the stack...
# Pushing frame 2753 onto the stack...
# Pushing frame 2754 onto the stack...
# Pushing frame 2755 onto the stack...
# Pushing frame 2756 onto the stack...
# Pushing frame 2757 onto the stack...
# Pushing frame 2758 onto the stack...
# Pushing frame 2759 onto the stack...
# Pushing frame 2760 onto the stack...
# Pushing frame 2761 onto the stack...
# Pushing frame 2762 onto the stack...
# Pushing frame 2763 onto the stack...
# Pushing frame 2764 onto the stack...
# Pushing frame 2765 onto the stack...
# Pushing frame 2766 onto the stack...
# Pushing frame 2767 onto the stack...
# Pushing frame 2768 onto the stack...
# Pushing frame 2769 onto the stack...
# Pushing frame 2770 onto the stack...
# Pushing frame 2771 onto the stack...
# Pushing frame 2772 onto the stack...
# Pushing frame 2773 onto the stack...
# Pushing frame 2774 onto the stack...
# Pushing frame 2775 onto the stack...
# Pushing frame 2776 onto the stack...
# Pushing frame 2777 onto the stack...
# Pushing frame 2778 onto the stack...
# Pushing frame 2779 onto the stack...
# Pushing frame 2780 onto the stack...
# Pushing frame 2781 onto the stack...
# Pushing frame 2782 onto the stack...
# Pushing frame 2783 onto the stack...
# Pushing frame 2784 onto the stack...
# Pushing frame 2785 onto the stack...
# Pushing frame 2786 onto the stack...
# Pushing frame 2787 onto the stack...
# Pushing frame 2788 onto the stack...
# Pushing frame 2789 onto the stack...
# Pushing frame 2790 onto the stack...
# Pushing frame 2791 onto the stack...
# Pushing frame 2792 onto the stack...
# Pushing frame 2793 onto the stack...
# Pushing frame 2794 onto the stack...
# Pushing frame 2795 onto the stack...
# Pushing frame 2796 onto the stack...
# Pushing frame 2797 onto the stack...
# Pushing frame 2798 onto the stack...
# Pushing frame 2799 onto the stack...
# Pushing frame 2800 onto the stack...
# Pushing frame 2801 onto the stack...
# Pushing frame 2802 onto the stack...
# Pushing frame 2803 onto the stack...
# Pushing frame 2804 onto the stack...
# Pushing frame 2805 onto the stack...
# Pushing frame 2806 onto the stack...
# Pushing frame 2807 onto the stack...
# Pushing frame 2808 onto the stack...
# Pushing frame 2809 onto the stack...
# Pushing frame 2810 onto the stack...
# Pushing frame 2811 onto the stack...
# Pushing frame 2812 onto the stack...
# Pushing frame 2813 onto the stack...
# Pushing frame 2814 onto the stack...
# Pushing frame 2815 onto the stack...
# Pushing frame 2816 onto the stack...
# Pushing frame 2817 onto the stack...
# Pushing frame 2818 onto the stack...
# Pushing frame 2819 onto the stack...
# Pushing frame 2820 onto the stack...
# Pushing frame 2821 onto the stack...
# Pushing frame 2822 onto the stack...
# Pushing frame 2823 onto the stack...
# Pushing frame 2824 onto the stack...
# Pushing frame 2825 onto the stack...
# Pushing frame 2826 onto the stack...
# Pushing frame 2827 onto the stack...
# Pushing frame 2828 onto the stack...
# Pushing frame 2829 onto the stack...
# Pushing frame 2830 onto the stack...
# Pushing frame 2831 onto the stack...
# Pushing frame 2832 onto the stack...
# Pushing frame 2833 onto the stack...
# Pushing frame 2834 onto the stack...
# Pushing frame 2835 onto the stack...
# Pushing frame 2836 onto the stack...
# Pushing frame 2837 onto the stack...
# Pushing frame 2838 onto the stack...
# Pushing frame 2839 onto the stack...
# Pushing frame 2840 onto the stack...
# Pushing frame 2841 onto the stack...
# Pushing frame 2842 onto the stack...
# Pushing frame 2843 onto the stack...
# Pushing frame 2844 onto the stack...
# Pushing frame 2845 onto the stack...
# Pushing frame 2846 onto the stack...
# Pushing frame 2847 onto the stack...
# Pushing frame 2848 onto the stack...
# Pushing frame 2849 onto the stack...
# Pushing frame 2850 onto the stack...
# Pushing frame 2851 onto the stack...
# Pushing frame 2852 onto the stack...
# Pushing frame 2853 onto the stack...
# Pushing frame 2854 onto the stack...
# Pushing frame 2855 onto the stack...
# Pushing frame 2856 onto the stack...
# Pushing frame 2857 onto the stack...
# Pushing frame 2858 onto the stack...
# Pushing frame 2859 onto the stack...
# Pushing frame 2860 onto the stack...
# Pushing frame 2861 onto the stack...
# Pushing frame 2862 onto the stack...
# Pushing frame 2863 onto the stack...
# Pushing frame 2864 onto the stack...
# Pushing frame 2865 onto the stack...
# Pushing frame 2866 onto the stack...
# Pushing frame 2867 onto the stack...
# Pushing frame 2868 onto the stack...
# Pushing frame 2869 onto the stack...
# Pushing frame 2870 onto the stack...
# Pushing frame 2871 onto the stack...
# Pushing frame 2872 onto the stack...
# Pushing frame 2873 onto the stack...
# Pushing frame 2874 onto the stack...
# Pushing frame 2875 onto the stack...
# Pushing frame 2876 onto the stack...
# Pushing frame 2877 onto the stack...
# Pushing frame 2878 onto the stack...
# Pushing frame 2879 onto the stack...
# Pushing frame 2880 onto the stack...
# Pushing frame 2881 onto the stack...
# Pushing frame 2882 onto the stack...
# Pushing frame 2883 onto the stack...
# Pushing frame 2884 onto the stack...
# Pushing frame 2885 onto the stack...
# Pushing frame 2886 onto the stack...
# Pushing frame 2887 onto the stack...
# Pushing frame 2888 onto the stack...
# Pushing frame 2889 onto the stack...
# Pushing frame 2890 onto the stack...
# Pushing frame 2891 onto the stack...
# Pushing frame 2892 onto the stack...
# Pushing frame 2893 onto the stack...
# Pushing frame 2894 onto the stack...
# Pushing frame 2895 onto the stack...
# Pushing frame 2896 onto the stack...
# Pushing frame 2897 onto the stack...
# Pushing frame 2898 onto the stack...
# Pushing frame 2899 onto the stack...
# Pushing frame 2900 onto the stack...
# Pushing frame 2901 onto the stack...
# Pushing frame 2902 onto the stack...
# Pushing frame 2903 onto the stack...
# Pushing frame 2904 onto the stack...
# Pushing frame 2905 onto the stack...
# Pushing frame 2906 onto the stack...
# Pushing frame 2907 onto the stack...
# Pushing frame 2908 onto the stack...
# Pushing frame 2909 onto the stack...
# Pushing frame 2910 onto the stack...
# Pushing frame 2911 onto the stack...
# Pushing frame 2912 onto the stack...
# Pushing frame 2913 onto the stack...
# Pushing frame 2914 onto the stack...
# Pushing frame 2915 onto the stack...
# Pushing frame 2916 onto the stack...
# Pushing frame 2917 onto the stack...
# Pushing frame 2918 onto the stack...
# Pushing frame 2919 onto the stack...
# Pushing frame 2920 onto the stack...
# Pushing frame 2921 onto the stack...
# Pushing frame 2922 onto the stack...
# Pushing frame 2923 onto the stack...
# Pushing frame 2924 onto the stack...
# Pushing frame 2925 onto the stack...
# Pushing frame 2926 onto the stack...
# Pushing frame 2927 onto the stack...
# Pushing frame 2928 onto the stack...
# Pushing frame 2929 onto the stack...
# Pushing frame 2930 onto the stack...
# Pushing frame 2931 onto the stack...
# Pushing frame 2932 onto the stack...
# Pushing frame 2933 onto the stack...
# Pushing frame 2934 onto the stack...
# Pushing frame 2935 onto the stack...
# Pushing frame 2936 onto the stack...
# Pushing frame 2937 onto the stack...
# Pushing frame 2938 onto the stack...
# Pushing frame 2939 onto the stack...
# Pushing frame 2940 onto the stack...
# Pushing frame 2941 onto the stack...
# Pushing frame 2942 onto the stack...
# Pushing frame 2943 onto the stack...
# Pushing frame 2944 onto the stack...
# Pushing frame 2945 onto the stack...
# Pushing frame 2946 onto the stack...
# Pushing frame 2947 onto the stack...
# Pushing frame 2948 onto the stack...
# Pushing frame 2949 onto the stack...
# Pushing frame 2950 onto the stack...
# Pushing frame 2951 onto the stack...
# Pushing frame 2952 onto the stack...
# Pushing frame 2953 onto the stack...
# Pushing frame 2954 onto the stack...
# Pushing frame 2955 onto the stack...
# Pushing frame 2956 onto the stack...
# Pushing frame 2957 onto the stack...
# Pushing frame 2958 onto the stack...
# Pushing frame 2959 onto the stack...
# Pushing frame 2960 onto the stack...
# Pushing frame 2961 onto the stack...
# Pushing frame 2962 onto the stack...
# Pushing frame 2963 onto the stack...
# Pushing frame 2964 onto the stack...
# Pushing frame 2965 onto the stack...
# Pushing frame 2966 onto the stack...
# Pushing frame 2967 onto the stack...
# Pushing frame 2968 onto the stack...
# Pushing frame 2969 onto the stack...
# Pushing frame 2970 onto the stack...
# Pushing frame 2971 onto the stack...
# Pushing frame 2972 onto the stack...
# Pushing frame 2973 onto the stack...
# Pushing frame 2974 onto the stack...
# Pushing frame 2975 onto the stack...
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[6], line 6
#       3     recursive_crash(n + 1)
#       5 # Uncommenting this line will crash the kernel with RecursionError
# ----> 6 recursive_crash(1)
#
# Cell In[6], line 3, in recursive_crash(n)
#       1 def recursive_crash(n):
#       2     print(f"Pushing frame {n} onto the stack...")
# ----> 3     recursive_crash(n + 1)
#
# Cell In[6], line 3, in recursive_crash(n)
#       1 def recursive_crash(n):
#       2     print(f"Pushing frame {n} onto the stack...")
# ----> 3     recursive_crash(n + 1)
#
#     [... skipping similar frames: recursive_crash at line 3 (2971 times)]
#
# Cell In[6], line 3, in recursive_crash(n)
#       1 def recursive_crash(n):
#       2     print(f"Pushing frame {n} onto the stack...")
# ----> 3     recursive_crash(n + 1)
#
# Cell In[6], line 2, in recursive_crash(n)
#       1 def recursive_crash(n):
# ----> 2     print(f"Pushing frame {n} onto the stack...")
#       3     recursive_crash(n + 1)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:3056, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3054 if not data:
#    3055     return result
# -> 3056 execution_count = self.execution_count
#    3057 output_stream = None
#    3058 outputs_by_counter = self.history_manager.outputs
#
# File ~\AppData\Roaming\Python\Python312\site-packages\traitlets\traitlets.py:687, in TraitType.__get__(self, obj, cls)
#     685     return self
#     686 else:
# --> 687     return t.cast(G, self.get(obj, cls))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\traitlets\traitlets.py:666, in TraitType.get(self, obj, cls)
#     664     raise TraitError("Unexpected error in TraitType: default value not set properly") from e
#     665 else:
# --> 666     return t.cast(G, value)
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ---
#
# ## 潮 Mini-Challenge: The Syntax Validator
#
# Code Editors (VS Code) use Stacks to check if your parentheses are balanced.
# Input: `"{ [ ( ) ] }"` $\rightarrow$ Valid.
# Input: `"{ [ ( ] ) }"` $\rightarrow$ Invalid (Closed `]` before closing `)`).
#
# **Task:** Implement `is_balanced(text)` using a Stack.

# %%
def is_balanced(text: str) -> bool:
    stack = Stack()
    pairs = {")": "(", "]": "[", "}": "{"}
    
    for char in text:
        if char in "({[":
            stack.push(char)
        elif char in ")}]":
            if stack.is_empty():
                return False
            top = stack.pop()
            if top != pairs[char]:
                return False
    
    return stack.is_empty()

print(f"Is '{{[]}}' balanced? {is_balanced('{[]}')}")
print(f"Is '([)]' balanced? {is_balanced('([)]')}")
# Out:
# Is '{[]}' balanced? True
# Is '([)]' balanced? False

# %% [markdown]
# ---
#
# ## 🌟 Core Insight for Your CSE Career
#
# ### 1. Stack = Depth First Search (DFS)
# Whenever you need to explore a Graph (maze, social network, file system) by going **deep** before going wide, you use a Stack.
# -   **Recursion** is just an implicit Stack (using the OS Call Stack).
# -   **Iterative DFS** is an explicit Stack (using a `list` loop).
#
# ### 2. Why List is OK here
# For Stacks, `list.append()` and `list.pop()` happen at the **end** of the memory block. This is **$O(1)$**. Therefore, Python's built-in list is a perfect, high-performance Stack. You rarely need a custom class in production.
